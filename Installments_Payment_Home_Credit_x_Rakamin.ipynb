# %% [markdown]
# <a href="https://colab.research.google.com/github/MikailNabilJ/Installments-Payments_Home-Credit-x-Rakamin/blob/main/Installments_Payment_Home_Credit_x_Rakamin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Description
#
# *   The "installments_payments.csv" represents repayment history for the previously disbursed credits in Home Credit related to the loans in the sample.
# *   There is a) one row for every payment that was made plus b) one row each for missed payment.
# *   One row is equivalent to one payment of one installment OR one installment corresponding to one payment of one previous Home Credit credit related to loans in our sample.

# %% [markdown]
# **Import Paket dan modul yang dibutuhkan**

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Installments Payments

# %% [markdown]
# **Menampilkan Data Installments Payments**

# %%
col_description = pd.read_csv('/content/installments_payments.csv', encoding='latin')
pd.set_option('display.max_info_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
installments_payments = pd.read_csv('/content/installments_payments.csv')
installments_payments.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
# 3     2452527      199697                     1.0                      3
# 4     2714724      167756                     1.0                      2
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0          -1180.0             -1187.0        6948.360     6948.360
# 1          -2156.0             -2156.0        1716.525     1716.525
# 2            -63.0               -63.0       25425.000    25425.000
# 3          -2418.0             -2426.0       24350.130    24350.130
# 4          -1383.0             -1366.0        2165.040     2160.585
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
# UKURAN DATA
print('\nSize of installments_payments data:', installments_payments.shape)
# Out:
# Size of installments_payments data: (217030, 8)

# %%
# TIPE DATA SETIAP KOLOM
installments_payments.dtypes
# Out:
# SK_ID_PREV                  int64
# SK_ID_CURR                  int64
# NUM_INSTALMENT_VERSION    float64
# NUM_INSTALMENT_NUMBER       int64
# DAYS_INSTALMENT           float64
# DAYS_ENTRY_PAYMENT        float64
# AMT_INSTALMENT            float64
# AMT_PAYMENT               float64
# dtype: object

# %%
# JUMLAH NILAI NULL DI SETIAP KOLOM
installments_payments.isna().sum().sort_values(ascending=False)
# Out:
# SK_ID_PREV                0
# SK_ID_CURR                0
# NUM_INSTALMENT_VERSION    0
# NUM_INSTALMENT_NUMBER     0
# DAYS_INSTALMENT           0
# DAYS_ENTRY_PAYMENT        0
# AMT_INSTALMENT            0
# AMT_PAYMENT               0
# dtype: int64

# %%
# PERSENTASE NILAI NULL DI SETIAP KOLOM
(installments_payments.isna().sum() / installments_payments.shape[0]).sort_values(ascending=False)
# Out:
# SK_ID_PREV                0.0
# SK_ID_CURR                0.0
# NUM_INSTALMENT_VERSION    0.0
# NUM_INSTALMENT_NUMBER     0.0
# DAYS_INSTALMENT           0.0
# DAYS_ENTRY_PAYMENT        0.0
# AMT_INSTALMENT            0.0
# AMT_PAYMENT               0.0
# dtype: float64

# %% [markdown]
# Dua kolom: hari dan jumlah yang sebenarnya dibayar pelanggan (**DAYS_ENTRY_PAYMENT** dan **AMT_PAYMENT**) menyertakan jumlah nilai null yang sama
#
# **0% klien belum membayar kredit sebelumnya untuk angsuran ini atau semua klien membayar lunas kredit**

# %% [markdown]
# # Ringkasan Data

# %%
installments_payments.describe()
# Out:
#          SK_ID_PREV     SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# count  2.170300e+05  217030.000000           217030.000000
# mean   1.900748e+06  150165.426969                0.856421
# std    5.355474e+05   28937.937487                1.026157
# min    1.000005e+06  100002.000000                0.000000
# 25%    1.431028e+06  125106.500000                0.000000
# 50%    1.894481e+06  150089.500000                1.000000
# 75%    2.366030e+06  175311.000000                1.000000
# max    2.843491e+06  199999.000000               35.000000
#
#        NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# count          217030.000000    217030.000000       217030.000000
# mean               19.108487     -1043.648215        -1052.388144
# std                27.052913       801.958664          801.541369
# min                 1.000000     -2922.000000        -3026.000000
# 25%                 4.000000     -1658.000000        -1667.000000
# ...

# %% [markdown]
# Rata-rata **AMT_INSTALLMENTS** (jumlah angsuran yang ditentukan pada angsuran ini adalah) sama dengan **AMT_PAYMENTS** (jumlah yang sebenarnya dibayarkan klien pada angsuran ini) menunjukkan:
#
# **Semua pinjaman dibayar lunas tepat waktu**

# %% [markdown]
# # Histogram

# %%
installments_payments.iloc[:,4:6].hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'DAYS_INSTALMENT'}>,
#         <Axes: title={'center': 'DAYS_ENTRY_PAYMENT'}>]], dtype=object)

# %%
sns.pairplot(installments_payments.iloc[:,4:8], corner=True)

# %% [markdown]
# Histogram **Installment Day** dan **Actually Paid** menunjukkan bahwa pembayaran pelanggan tepat waktu

# %% [markdown]
# # Korelasi

# %%
installments_payments.corr()
# Out:
#                         SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# SK_ID_PREV                1.000000    0.002068                0.005705
# SK_ID_CURR                0.002068    1.000000                0.000257
# NUM_INSTALMENT_VERSION    0.005705    0.000257                1.000000
# NUM_INSTALMENT_NUMBER    -0.005616    0.006698               -0.328443
# DAYS_INSTALMENT           0.007362    0.002847                0.132928
# DAYS_ENTRY_PAYMENT        0.007393    0.002936                0.130432
# AMT_INSTALMENT            0.004334   -0.001047                0.169489
# AMT_PAYMENT               0.003060   -0.001385                0.178241
#
#                         NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  \
# SK_ID_PREV                          -0.005616         0.007362
# SK_ID_CURR                           0.006698         0.002847
# NUM_INSTALMENT_VERSION              -0.328443         0.132928
# NUM_INSTALMENT_NUMBER                1.000000         0.090637
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(installments_payments.corr())

plt.show()

# %% [markdown]
# **Tidak ada kolom yang dihapus**
#
# SK_ID_PREV, SK_ID_CURR, NUM_INSTALMENT_VERSION dan
# NUM_INSTALMENT_NUMBER bentuk kunci komposit
#
# AMT_PAYMENT dan AMT_INSTALLMENT memiliki korelasi tinggi tetapi merupakan variabel penting

# %% [markdown]
# # **Insight and Recomendation**
#
# # *Insight*
#
# 1. Dua kolom: hari dan jumlah yang sebenarnya dibayar pelanggan (DAYS_ENTRY_PAYMENT dan AMT_PAYMENT) menyertakan jumlah nilai null yang sama
#
#   **0% klien belum membayar kredit sebelumnya untuk angsuran ini atau semua klien membayar lunas kredit**
#
# 2. Rata-rata AMT_INSTALLMENTS (jumlah angsuran yang ditentukan pada angsuran ini adalah) sama dengan AMT_PAYMENTS (jumlah yang sebenarnya dibayarkan klien pada angsuran ini) menunjukkan:
#
#   **Semua pinjaman dibayar lunas tepat waktu**
#
# 3. AMT_PAYMENT dan AMT_INSTALLMENT memiliki korelasi tinggi sehingga merupakan variabel penting
#
# # *Recomendation*
#
# 1.   Tidak terdapat masalah dalam Installments Payments dan, Home Credit harus tetap menjaga kenyamanan klien dari segi bonus kredit ditambah dan sistem aplikasinya harus benar-benar ketat sehingga Home Credit dapat menyeleksi klien sesuai target misalnya : Umur yang memadai, gaji yang sesuai agar tidak terdapat keterlambatan pembayaran maupun galbay, memakai status BI Checking untuk dapat meng-tracking klien yang cocok.
